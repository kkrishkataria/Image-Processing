# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
array=np.full([640,640],10)

# %%
plt.imshow(array,cmap='gray')

# %%
import numpy as np

R = 255
G = 255
B = 255

rgb = np.vstack((R, G, B))

plt.imshow(rgb,cmap='gray')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('Sunflower_from_Silesia2.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gray1 = np.zeros((img.shape[0], img.shape[1]), dtype=np.uint8)

for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        gray1[i, j] = np.mean(img[i, j])

plt.imshow(gray1, cmap='gray')
plt.axis('off')
plt.show()

# %%
gray2=cv2.imread('Sunflower_from_Silesia2.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(gray2,cmap='gray')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


img = cv2.imread('Sunflower_from_Silesia2.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


gray3 = np.zeros((img.shape[0], img.shape[1]), dtype=np.uint8)

for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        R = img[i, j, 0]
        G = img[i, j, 1]
        B = img[i, j, 2]

        gray3[i, j] = 0.299 * R + 0.587 * G + 0.114 * B
plt.imshow(gray3, cmap='gray')

# %%
import numpy as np

def mse(img1, img2):
    return np.mean(abs(img1.astype(np.float32) - img2.astype(np.float32))/np.mean(img1))

error1 = mse(gray2, gray1)
error2 = mse(gray2, gray3)

print("Error Percentage (Original vs Image1):", error1*100)
print("Error Percentage (Original vs Image2):", error2*100)
# Out:
# Error Percentage (Original vs Image1): 18.844485612900144
# Error Percentage (Original vs Image2): 0.44869212047507717
